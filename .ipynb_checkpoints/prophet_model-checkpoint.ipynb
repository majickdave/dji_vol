# %%
from fbprophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('dji.csv', header=1, usecols=[0,1,2,3,4])

df.head()
# Out:
#    Unnamed: 0      Date  Dow Jones  value  RIS Forecast Volume  \
# 0         NaN  1/4/2016          17148.94                 6547
# 1         NaN  1/5/2016          17158.66                 4328
# 2         NaN  1/6/2016          16906.51                 3987
# 3         NaN  1/7/2016          16514.10                 4006
# 4         NaN  1/8/2016          16346.45                 4107
#
#    RIS Actual Volume
# 0               6886
# 1               4928
# 2               3713
# 3               3910
# 4               3797

# %%
df = df[['Date','RIS Actual Volume']]

# %%
df.columns = ['ds','y']

# %%
df['ds'] = pd.to_datetime(df['ds'])
df.head()
# Out:
#           ds     y
# 0 2016-01-04  6886
# 1 2016-01-05  4928
# 2 2016-01-06  3713
# 3 2016-01-07  3910
# 4 2016-01-08  3797

# %%
# Python
m = Prophet(daily_seasonality=True)
m.fit(df)

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 1520 2021-08-09
# 1521 2021-08-10
# 1522 2021-08-11
# 1523 2021-08-12
# 1524 2021-08-13

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 1520 2021-08-09  2879.897353  2343.530792  3388.946499
# 1521 2021-08-10  2278.238238  1794.462459  2779.999565
# 1522 2021-08-11  2012.349621  1527.373303  2533.095989
# 1523 2021-08-12  1885.343096  1386.321815  2407.931905
# 1524 2021-08-13  1951.975861  1448.324164  2451.790399

# %%
# Python
fig1 = m.plot(forecast)

# %%
# Python
fig2 = m.plot_components(forecast)

# %%
forecast[forecast['ds']=='2019-09-10'][['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 925 2019-09-10  2241.901692  1743.386344  2689.093335
